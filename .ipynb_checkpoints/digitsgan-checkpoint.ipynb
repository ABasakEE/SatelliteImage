# %% [markdown]
# # Generative Adversarial Networks
# GANs are a type of Deep Learning Model in which we have **two competing architectures**. In a typical GAN, we have a **generator** and a **discriminator**. The generator tries to generate _something meaningful_ from **random noise**, while the discriminator tries to determine whether the output from the generator is _real or fake_ by looking at the _actual real output_ fed to it.
#
# <img title="GAN" alt="GAN" src="Images/GAN.png" width="600" height="300">
#
# In this way, the two models try to compete against each other and over time, settle down to an equilibrium. At that point, the generator becomes good enough to fool the discriminator. During this point, the discriminator and _no longer distinguish_ the generator's outputs sufficiently well from the real output and settles down to a 0.5 probability state.

# %%
#importing relevant modules
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import datasets, layers, models, losses, Input
import matplotlib.pyplot as plt
import numpy as np
import tensorflow_datasets as tfds

#importing modules for function callback
import os
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.callbacks import Callback

# %%
def scale_images(data): 
    image = data['image']
    return (tf.cast(image, tf.float32) / 127.5)-1

# %%
# Load the dataset 
ds = tfds.load('mnist', split='train')
# Running the dataset through the scale_images preprocessing step
ds = ds.map(scale_images) 
# Cache the dataset for that batch 
ds = ds.cache()
# Shuffle it up 
ds = ds.shuffle(60000)
# Batch into 128 images per sample
ds = ds.batch(128)
# Reduces the likelihood of bottlenecking 
ds = ds.prefetch(64)

# %%
#create the generator model which will try to generate images from random noise
#create a CNN for this which will now upscale data 

def generator_model():
    model=Sequential()

    #first block to create the data from random noise
    model.add(Input(shape=(128,)))
    model.add(layers.Dense(7*7*128))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Reshape((7,7,128)))   

    #create an upsampling layer
    model.add(layers.Conv2DTranspose(256,(5,5),strides=(2,2),padding='same',use_bias='false'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))

    #create another upsampling layer
    model.add(layers.Conv2DTranspose(128,(5,5),strides=(2,2),padding='same',use_bias='false'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))  

    #start applying ConvNet layers
    model.add(layers.Conv2D(64,(5,5),strides=(1,1),padding='same',use_bias='false'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))

    model.add(layers.Conv2D(64,(5,5),strides=(1,1),padding='same',use_bias='false'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))

    #generate the final layer
    model.add(layers.Conv2D(1,(4,4),strides=(1,1),padding='same',use_bias='false',activation='tanh'))   
    
    return model

# %%
generator = generator_model()
generator.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 6272)                │         809,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 6272)                │          25,088 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 14, 14, 256)         │         819,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 28, 28, 128)         │         819,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 64)          │         204,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 28, 28, 64)          │         102,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 28, 28, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 1)           │           1,025 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,783,361 (10.62 MB)
#  Trainable params: 2,769,793 (10.57 MB)
#  Non-trainable params: 13,568 (53.00 KB)

# %%
#visualize some images created by the model

#display some images from the dataset
num_row = 2
num_col = 3

num = num_row*num_col

#get predictions from random noise
images = generator.predict(np.random.rand(num,128,1))

# plot images
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for i in range(num):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(images[i], cmap='gray')
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721577345.278728      75 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
#create the discriminator model
def discrim_model():
    model=Sequential()

    #1st ConvNet block
    model.add(Input(shape=(28,28,1)))    
    model.add(layers.Conv2D(32,(2,2)))
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Dropout(0.3))

    #2nd ConvNet block
    model.add(layers.Conv2D(64,(2,2)))
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Dropout(0.3))

    #1st dense layer
    model.add(layers.Flatten())
    model.add(layers.Dense(64))
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Dropout(0.3))

    #output layer
    model.add(layers.Dense(1,activation='tanh'))
    return model

# %%
discriminator = discrim_model()
discriminator.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 27, 27, 32)          │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)            │ (None, 27, 27, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 27, 27, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 26, 26, 64)          │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)            │ (None, 26, 26, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 26, 26, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 43264)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │       2,768,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,777,441 (10.60 MB)
#  Trainable params: 2,777,441 (10.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#setup losses and optimizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

g_opt =  Adam(learning_rate=0.00002,beta_1=0.5)
d_opt = Adam(learning_rate=0.00002,beta_1=0.5) #discriminator must learn slower than generator in order to allow generator to adapt
#and produce something image like from the random noise

g_loss =  BinaryCrossentropy() #if the generator manages to spot which image was made by the generator
d_loss =  BinaryCrossentropy() #if the discriminator manages to fool the generator

# %%
#build a custom subclassed Model to train both generator and discriminator
from tensorflow.keras.models import Model

class DigitsGAN(Model):
    
    def __init__(self,generator,discriminator,*args,**kwargs):
        super().__init__(*args, **kwargs) #passing any arguments or keyword arguments received to the base class
        self.generator=generator
        self.discriminator=discriminator
        
    def compile(self,g_opt,d_opt,g_loss,d_loss,*args,**kwargs): #defining a custom method for performing the training steps
        super().compile(*args,**kwargs) #passing any arguments or keyword arguments received to the base class

        #create attributes for the optimizers and losses
        self.g_opt=g_opt
        self.d_opt=d_opt
        self.g_loss=g_loss
        self.d_loss=d_loss      
        
    def train_step(self,batch): 
        #pass a batch of images to the generator
        real_images=batch

        #what the discriminator will generate given random noise
        fake_images = self.generator(tf.random.normal((128, 128, 1)), training=False)
        
        #Train the discriminator
        with tf.GradientTape() as d_tape:
            
            #Pass real and fake images to the discriminator model        
            pred_real=self.discriminator(real_images,training=True)
            pred_fake=self.discriminator(fake_images,training=True)
            pred=tf.concat([pred_real,pred_fake],axis=0)
            
            #Create labels for the real and fake images
            #classify the real as 0s and the fakes as 1s
            labels=tf.concat([tf.zeros_like(pred_real),tf.ones_like(pred_fake)],axis=0)
            
            #Add some noise to the outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(pred_real)) #add some noise on top of the generator output
            noise_fake = -0.15*tf.random.uniform(tf.shape(pred_fake))
            labels += tf.concat([noise_real, noise_fake], axis=0)
            
            #Calculate the losses incurred by the discriminator
            total_d_loss=self.d_loss(labels,pred) #the difference between real and fake values

        #calculate the values for the gradients on each level of the discriminator        
        d_grad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables) 

        #apply backpropagation on the trainable variables of the discriminator to make it learn better        
        self.d_opt.apply_gradients(zip(d_grad, self.discriminator.trainable_variables))            

        #Train the generator
        with tf.GradientTape() as g_tape:
            # Generate some new images
            gen_images = self.generator(tf.random.normal((128,128,1)), training=True) #here we want to train the generator at this step
                                        
            # Create the predicted labels
            predicted_labels = self.discriminator(gen_images, training=False) #we do not want to train the discriminator here
                                        
            #in order for the generator to trick the discriminator, we will pretend that the images created
            #by the generator are real, i.e., it will has label 0 as seen in the discriminator training
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels) 

        #calculate the values for the gradients on each level of the discriminator        
        g_grad = g_tape.gradient(total_g_loss, self.generator.trainable_variables) 

        #apply backpropagation on the trainable variables of the discriminator to make it learn better        
        self.g_opt.apply_gradients(zip(g_grad, self.generator.trainable_variables))   

        return {"d_loss":total_d_loss, "g_loss":total_g_loss}

# %%
#instantianting the class for training 
digits_gan = DigitsGAN(generator, discriminator)
digits_gan.compile(g_opt, d_opt, g_loss, d_loss)

# %%
path='digits'
if not os.path.exists(path):
    os.makedirs('digits')

# %%
#defining the callback
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=128):
        self.i=0
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        self.i+=1
        if (self.i==50):
            random_latent_vectors = tf.random.uniform((self.num_img, self.latent_dim,1))
            generated_images = self.model.generator(random_latent_vectors)
            generated_images = generated_images*127.5+127.5
            generated_images.numpy()
            for i in range(self.num_img):
                img = array_to_img(generated_images[i])
                img.save(os.path.join('digits', f'generated_img_{epoch}_{i}.png'))
            self.i=0

# %%
#train the model
hist = digits_gan.fit(ds, epochs=500, callbacks=[ModelMonitor()])
# Out:
# Epoch 1/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - d_loss: 0.8487 - g_loss: 0.1458
# Epoch 2/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.8356 - g_loss: 0.1003
# Epoch 3/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6677 - g_loss: 0.1027
# Epoch 4/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7905 - g_loss: 0.0680
# Epoch 5/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7473 - g_loss: 0.0997
# Epoch 6/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7317 - g_loss: 0.1319
# Epoch 7/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7172 - g_loss: 0.1532
# Epoch 8/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7097 - g_loss: 0.1657
# Epoch 9/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7014 - g_loss: 0.1681
# Epoch 10/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6980 - g_loss: 0.1718
# Epoch 11/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6951 - g_loss: 0.1788
# Epoch 12/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6923 - g_loss: 0.1741
# Epoch 13/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6912 - g_loss: 0.1708
# Epoch 14/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6912 - g_loss: 0.1643
# Epoch 15/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6908 - g_loss: 0.1584
# Epoch 16/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6890 - g_loss: 0.1551
# Epoch 17/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6877 - g_loss: 0.1548
# Epoch 18/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6904 - g_loss: 0.1793
# Epoch 19/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6857 - g_loss: 0.1989
# Epoch 20/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6850 - g_loss: 0.1964
# Epoch 21/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6840 - g_loss: 0.1952
# Epoch 22/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6838 - g_loss: 0.2057
# Epoch 23/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6822 - g_loss: 0.2161
# Epoch 24/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6867 - g_loss: 0.3027
# Epoch 25/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6815 - g_loss: 0.2847
# Epoch 26/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6824 - g_loss: 0.2925
# Epoch 27/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6833 - g_loss: 0.3000
# Epoch 28/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6823 - g_loss: 0.3056
# Epoch 29/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6824 - g_loss: 0.3246
# Epoch 30/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6828 - g_loss: 0.3269
# Epoch 31/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6840 - g_loss: 0.3352
# Epoch 32/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6823 - g_loss: 0.3531
# Epoch 33/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6827 - g_loss: 0.3602
# Epoch 34/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6820 - g_loss: 0.3755
# Epoch 35/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6813 - g_loss: 0.3790
# Epoch 36/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6811 - g_loss: 0.3943
# Epoch 37/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6804 - g_loss: 0.4010
# Epoch 38/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6794 - g_loss: 0.4055
# Epoch 39/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6802 - g_loss: 0.4190
# Epoch 40/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6800 - g_loss: 0.4355
# Epoch 41/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6830 - g_loss: 0.5259
# Epoch 42/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6789 - g_loss: 0.5769
# Epoch 43/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6800 - g_loss: 0.5719
# Epoch 44/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6804 - g_loss: 0.5811
# Epoch 45/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6809 - g_loss: 0.5704
# Epoch 46/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6795 - g_loss: 0.5740
# Epoch 47/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6805 - g_loss: 0.5988
# Epoch 48/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6807 - g_loss: 0.6096
# Epoch 49/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6812 - g_loss: 0.6185
# Epoch 50/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 35s 74ms/step - d_loss: 0.6802 - g_loss: 0.6244
# Epoch 51/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6807 - g_loss: 0.6281
# Epoch 52/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6809 - g_loss: 0.6378
# Epoch 53/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6803 - g_loss: 0.6520
# Epoch 54/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6808 - g_loss: 0.6627
# Epoch 55/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6810 - g_loss: 0.6840
# Epoch 56/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6800 - g_loss: 0.6845
# Epoch 57/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6804 - g_loss: 0.6848
# Epoch 58/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6805 - g_loss: 0.7139
# Epoch 59/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6805 - g_loss: 0.7272
# Epoch 60/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6809 - g_loss: 0.7417
# Epoch 61/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6814 - g_loss: 0.7399
# Epoch 62/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6813 - g_loss: 0.7441
# Epoch 63/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6808 - g_loss: 0.7505
# Epoch 64/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6810 - g_loss: 0.7602
# Epoch 65/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6814 - g_loss: 0.7681
# Epoch 66/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6811 - g_loss: 0.7696
# Epoch 67/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6815 - g_loss: 0.7783
# Epoch 68/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6814 - g_loss: 0.7995
# Epoch 69/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6818 - g_loss: 0.7965
# Epoch 70/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6812 - g_loss: 0.8132
# Epoch 71/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6812 - g_loss: 0.8392
# Epoch 72/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6814 - g_loss: 0.8334
# Epoch 73/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6819 - g_loss: 0.8245
# Epoch 74/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6818 - g_loss: 0.8368
# Epoch 75/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6812 - g_loss: 0.8383
# Epoch 76/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6821 - g_loss: 0.8324
# Epoch 77/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6821 - g_loss: 0.8239
# Epoch 78/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6820 - g_loss: 0.8281
# Epoch 79/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6822 - g_loss: 0.8327
# Epoch 80/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6821 - g_loss: 0.8299
# Epoch 81/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6830 - g_loss: 0.8334
# Epoch 82/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6827 - g_loss: 0.8352
# Epoch 83/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6827 - g_loss: 0.8426
# Epoch 84/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6829 - g_loss: 0.8350
# Epoch 85/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 0.8390
# Epoch 86/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6827 - g_loss: 0.8415
# Epoch 87/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6830 - g_loss: 0.8458
# Epoch 88/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6837 - g_loss: 0.8308
# Epoch 89/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6830 - g_loss: 0.8439
# Epoch 90/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6833 - g_loss: 0.8533
# Epoch 91/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6842 - g_loss: 0.8379
# Epoch 92/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6846 - g_loss: 0.8381
# Epoch 93/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6842 - g_loss: 0.8384
# Epoch 94/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6846 - g_loss: 0.8502
# Epoch 95/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 0.8653
# Epoch 96/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6846 - g_loss: 0.8621
# Epoch 97/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6848 - g_loss: 0.8571
# Epoch 98/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6844 - g_loss: 0.8581
# Epoch 99/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6855 - g_loss: 0.8577
# Epoch 100/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6853 - g_loss: 0.8573
# Epoch 101/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6857 - g_loss: 0.8654
# Epoch 102/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6852 - g_loss: 0.8607
# Epoch 103/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6852 - g_loss: 0.8601
# Epoch 104/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6857 - g_loss: 0.8580
# Epoch 105/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6850 - g_loss: 0.8570
# Epoch 106/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6852 - g_loss: 0.8577
# Epoch 107/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6852 - g_loss: 0.8493
# Epoch 108/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.8503
# Epoch 109/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6854 - g_loss: 0.8501
# Epoch 110/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6862 - g_loss: 0.8430
# Epoch 111/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.8395
# Epoch 112/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6861 - g_loss: 0.8351
# Epoch 113/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6867 - g_loss: 0.8329
# Epoch 114/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6866 - g_loss: 0.8383
# Epoch 115/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6865 - g_loss: 0.8289
# Epoch 116/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6858 - g_loss: 0.8316
# Epoch 117/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6865 - g_loss: 0.8283
# Epoch 118/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6869 - g_loss: 0.8269
# Epoch 119/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6858 - g_loss: 0.8189
# Epoch 120/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6869 - g_loss: 0.8110
# Epoch 121/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6867 - g_loss: 0.8168
# Epoch 122/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6872 - g_loss: 0.8082
# Epoch 123/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6859 - g_loss: 0.8098
# Epoch 124/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.8033
# Epoch 125/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6866 - g_loss: 0.8019
# Epoch 126/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 73ms/step - d_loss: 0.6864 - g_loss: 0.7927
# Epoch 127/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6868 - g_loss: 0.7894
# Epoch 128/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6863 - g_loss: 0.7902
# Epoch 129/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7905
# Epoch 130/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6866 - g_loss: 0.7944
# Epoch 131/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6869 - g_loss: 0.7943
# Epoch 132/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6871 - g_loss: 0.7907
# Epoch 133/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6867 - g_loss: 0.7924
# Epoch 134/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6867 - g_loss: 0.7869
# Epoch 135/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6866 - g_loss: 0.7839
# Epoch 136/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7884
# Epoch 137/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6872 - g_loss: 0.7828
# Epoch 138/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6869 - g_loss: 0.7850
# Epoch 139/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6869 - g_loss: 0.7830
# Epoch 140/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6876 - g_loss: 0.7786
# Epoch 141/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7781
# Epoch 142/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6872 - g_loss: 0.7777
# Epoch 143/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6875 - g_loss: 0.7752
# Epoch 144/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7715
# Epoch 145/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6878 - g_loss: 0.7750
# Epoch 146/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6871 - g_loss: 0.7748
# Epoch 147/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6871 - g_loss: 0.7734
# Epoch 148/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6873 - g_loss: 0.7706
# Epoch 149/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6876 - g_loss: 0.7671
# Epoch 150/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6876 - g_loss: 0.7647
# Epoch 151/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6872 - g_loss: 0.7658
# Epoch 152/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6873 - g_loss: 0.7669
# Epoch 153/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6874 - g_loss: 0.7640
# Epoch 154/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6872 - g_loss: 0.7667
# Epoch 155/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6876 - g_loss: 0.7618
# Epoch 156/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6873 - g_loss: 0.7560
# Epoch 157/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6871 - g_loss: 0.7578
# Epoch 158/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7580
# Epoch 159/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6874 - g_loss: 0.7593
# Epoch 160/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7624
# Epoch 161/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6874 - g_loss: 0.7612
# Epoch 162/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6869 - g_loss: 0.7614
# Epoch 163/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6873 - g_loss: 0.7591
# Epoch 164/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6872 - g_loss: 0.7594
# Epoch 165/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6873 - g_loss: 0.7592
# Epoch 166/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6872 - g_loss: 0.7591
# Epoch 167/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7570
# Epoch 168/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7551
# Epoch 169/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6870 - g_loss: 0.7533
# Epoch 170/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6874 - g_loss: 0.7475
# Epoch 171/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7503
# Epoch 172/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6870 - g_loss: 0.7531
# Epoch 173/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7519
# Epoch 174/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6875 - g_loss: 0.7505
# Epoch 175/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6875 - g_loss: 0.7541
# Epoch 176/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6864 - g_loss: 0.7447
# Epoch 177/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6876 - g_loss: 0.7345
# Epoch 178/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6878 - g_loss: 0.7372
# Epoch 179/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7378
# Epoch 180/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7409
# Epoch 181/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7468
# Epoch 182/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6876 - g_loss: 0.7426
# Epoch 183/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6872 - g_loss: 0.7457
# Epoch 184/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7448
# Epoch 185/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6873 - g_loss: 0.7461
# Epoch 186/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7480
# Epoch 187/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6869 - g_loss: 0.7479
# Epoch 188/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7503
# Epoch 189/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7487
# Epoch 190/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6873 - g_loss: 0.7472
# Epoch 191/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7461
# Epoch 192/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6869 - g_loss: 0.7487
# Epoch 193/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6875 - g_loss: 0.7486
# Epoch 194/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7472
# Epoch 195/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6873 - g_loss: 0.7503
# Epoch 196/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7488
# Epoch 197/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6870 - g_loss: 0.7487
# Epoch 198/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6866 - g_loss: 0.7482
# Epoch 199/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7494
# Epoch 200/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7517
# Epoch 201/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7541
# Epoch 202/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6869 - g_loss: 0.7549
# Epoch 203/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7544
# Epoch 204/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6870 - g_loss: 0.7481
# Epoch 205/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6865 - g_loss: 0.7478
# Epoch 206/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7496
# Epoch 207/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7518
# Epoch 208/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6864 - g_loss: 0.7538
# Epoch 209/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7503
# Epoch 210/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6864 - g_loss: 0.7529
# Epoch 211/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6864 - g_loss: 0.7495
# Epoch 212/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6871 - g_loss: 0.7481
# Epoch 213/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7414
# Epoch 214/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6863 - g_loss: 0.7413
# Epoch 215/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7453
# Epoch 216/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7464
# Epoch 217/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6870 - g_loss: 0.7487
# Epoch 218/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6870 - g_loss: 0.7481
# Epoch 219/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6866 - g_loss: 0.7462
# Epoch 220/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6868 - g_loss: 0.7467
# Epoch 221/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6863 - g_loss: 0.7500
# Epoch 222/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6863 - g_loss: 0.7513
# Epoch 223/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6867 - g_loss: 0.7476
# Epoch 224/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6863 - g_loss: 0.7479
# Epoch 225/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6862 - g_loss: 0.7475
# Epoch 226/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6859 - g_loss: 0.7506
# Epoch 227/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6864 - g_loss: 0.7541
# Epoch 228/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6859 - g_loss: 0.7550
# Epoch 229/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.7533
# Epoch 230/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6859 - g_loss: 0.7552
# Epoch 231/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6870 - g_loss: 0.7557
# Epoch 232/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6865 - g_loss: 0.7572
# Epoch 233/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6862 - g_loss: 0.7539
# Epoch 234/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6863 - g_loss: 0.7553
# Epoch 235/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6866 - g_loss: 0.7530
# Epoch 236/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 72ms/step - d_loss: 0.6863 - g_loss: 0.7499
# Epoch 237/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6861 - g_loss: 0.7509
# Epoch 238/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.7533
# Epoch 239/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6856 - g_loss: 0.7502
# Epoch 240/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6857 - g_loss: 0.7504
# Epoch 241/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.7484
# Epoch 242/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6864 - g_loss: 0.7506
# Epoch 243/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6852 - g_loss: 0.7512
# Epoch 244/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.7493
# Epoch 245/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6860 - g_loss: 0.7495
# Epoch 246/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6855 - g_loss: 0.7517
# Epoch 247/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6857 - g_loss: 0.7511
# Epoch 248/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.7500
# Epoch 249/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6858 - g_loss: 0.7498
# Epoch 250/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6860 - g_loss: 0.7549
# Epoch 251/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6854 - g_loss: 0.7540
# Epoch 252/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6850 - g_loss: 0.7571
# Epoch 253/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6848 - g_loss: 0.7578
# Epoch 254/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6855 - g_loss: 0.7586
# Epoch 255/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6857 - g_loss: 0.7605
# Epoch 256/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6846 - g_loss: 0.7600
# Epoch 257/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6853 - g_loss: 0.7558
# Epoch 258/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6850 - g_loss: 0.7515
# Epoch 259/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6847 - g_loss: 0.7506
# Epoch 260/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6850 - g_loss: 0.7560
# Epoch 261/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6856 - g_loss: 0.7545
# Epoch 262/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6830 - g_loss: 0.7479
# Epoch 263/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6853 - g_loss: 0.7425
# Epoch 264/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6848 - g_loss: 0.7428
# Epoch 265/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6850 - g_loss: 0.7428
# Epoch 266/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6855 - g_loss: 0.7426
# Epoch 267/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6853 - g_loss: 0.7447
# Epoch 268/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6850 - g_loss: 0.7431
# Epoch 269/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6852 - g_loss: 0.7442
# Epoch 270/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6848 - g_loss: 0.7428
# Epoch 271/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6851 - g_loss: 0.7447
# Epoch 272/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6848 - g_loss: 0.7502
# Epoch 273/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6852 - g_loss: 0.7488
# Epoch 274/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6845 - g_loss: 0.7492
# Epoch 275/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6845 - g_loss: 0.7506
# Epoch 276/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6850 - g_loss: 0.7499
# Epoch 277/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6846 - g_loss: 0.7485
# Epoch 278/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6840 - g_loss: 0.7497
# Epoch 279/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6845 - g_loss: 0.7518
# Epoch 280/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6848 - g_loss: 0.7540
# Epoch 281/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6844 - g_loss: 0.7540
# Epoch 282/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6842 - g_loss: 0.7549
# Epoch 283/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6841 - g_loss: 0.7511
# Epoch 284/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6842 - g_loss: 0.7483
# Epoch 285/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6840 - g_loss: 0.7452
# Epoch 286/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6845 - g_loss: 0.7425
# Epoch 287/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6844 - g_loss: 0.7466
# Epoch 288/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6845 - g_loss: 0.7471
# Epoch 289/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6841 - g_loss: 0.7496
# Epoch 290/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6840 - g_loss: 0.7492
# Epoch 291/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 0.7481
# Epoch 292/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6843 - g_loss: 0.7484
# Epoch 293/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6841 - g_loss: 0.7522
# Epoch 294/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6839 - g_loss: 0.7528
# Epoch 295/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 0.7546
# Epoch 296/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 0.7545
# Epoch 297/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6842 - g_loss: 0.7558
# Epoch 298/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6839 - g_loss: 0.7569
# Epoch 299/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6834 - g_loss: 0.7593
# Epoch 300/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6839 - g_loss: 0.7595
# Epoch 301/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6839 - g_loss: 0.7607
# Epoch 302/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6836 - g_loss: 0.7591
# Epoch 303/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6831 - g_loss: 0.7615
# Epoch 304/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6832 - g_loss: 0.7601
# Epoch 305/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6837 - g_loss: 0.7605
# Epoch 306/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6834 - g_loss: 0.7611
# Epoch 307/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6837 - g_loss: 0.7680
# Epoch 308/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 0.7644
# Epoch 309/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6829 - g_loss: 0.7640
# Epoch 310/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6832 - g_loss: 0.7639
# Epoch 311/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6836 - g_loss: 0.7617
# Epoch 312/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6837 - g_loss: 0.7636
# Epoch 313/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6836 - g_loss: 0.7625
# Epoch 314/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6828 - g_loss: 0.7652
# Epoch 315/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6826 - g_loss: 0.7627
# Epoch 316/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 72ms/step - d_loss: 0.6832 - g_loss: 0.7628
# Epoch 317/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6828 - g_loss: 0.7590
# Epoch 318/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6829 - g_loss: 0.7599
# Epoch 319/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6830 - g_loss: 0.7611
# Epoch 320/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6833 - g_loss: 0.7636
# Epoch 321/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6829 - g_loss: 0.7643
# Epoch 322/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6831 - g_loss: 0.7624
# Epoch 323/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6825 - g_loss: 0.7636
# Epoch 324/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6822 - g_loss: 0.7626
# Epoch 325/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6832 - g_loss: 0.7628
# Epoch 326/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6823 - g_loss: 0.7590
# Epoch 327/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6827 - g_loss: 0.7677
# Epoch 328/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6828 - g_loss: 0.7675
# Epoch 329/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6825 - g_loss: 0.7642
# Epoch 330/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6826 - g_loss: 0.7652
# Epoch 331/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6828 - g_loss: 0.7669
# Epoch 332/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6816 - g_loss: 0.7679
# Epoch 333/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6825 - g_loss: 0.7701
# Epoch 334/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6820 - g_loss: 0.7666
# Epoch 335/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6821 - g_loss: 0.7691
# Epoch 336/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6816 - g_loss: 0.7699
# Epoch 337/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6817 - g_loss: 0.7636
# Epoch 338/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6813 - g_loss: 0.7681
# Epoch 339/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6814 - g_loss: 0.7676
# Epoch 340/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6809 - g_loss: 0.7654
# Epoch 341/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6805 - g_loss: 0.7549
# Epoch 342/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6805 - g_loss: 0.7567
# Epoch 343/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6813 - g_loss: 0.7602
# Epoch 344/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6832 - g_loss: 0.7749
# Epoch 345/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6822 - g_loss: 0.7735
# Epoch 346/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6814 - g_loss: 0.7735
# Epoch 347/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6816 - g_loss: 0.7746
# Epoch 348/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6817 - g_loss: 0.7790
# Epoch 349/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6810 - g_loss: 0.7790
# Epoch 350/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6811 - g_loss: 0.7765
# Epoch 351/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6817 - g_loss: 0.7761
# Epoch 352/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6818 - g_loss: 0.7832
# Epoch 353/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6816 - g_loss: 0.7877
# Epoch 354/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6812 - g_loss: 0.7890
# Epoch 355/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6799 - g_loss: 0.7931
# Epoch 356/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6803 - g_loss: 0.7850
# Epoch 357/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6801 - g_loss: 0.7806
# Epoch 358/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6805 - g_loss: 0.7814
# Epoch 359/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6798 - g_loss: 0.7777
# Epoch 360/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6817 - g_loss: 0.7793
# Epoch 361/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.4935 - g_loss: 1.6478
# Epoch 362/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.3504 - g_loss: 2.5155
# Epoch 363/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.3427 - g_loss: 2.6257
# Epoch 364/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3443 - g_loss: 2.6504
# Epoch 365/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3416 - g_loss: 2.7167
# Epoch 366/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3395 - g_loss: 2.7097
# Epoch 367/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3353 - g_loss: 2.7016
# Epoch 368/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3637 - g_loss: 3.0678
# Epoch 369/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3413 - g_loss: 2.9045
# Epoch 370/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3399 - g_loss: 2.7987
# Epoch 371/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3383 - g_loss: 2.7987
# Epoch 372/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3375 - g_loss: 2.7544
# Epoch 373/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 1.5703 - g_loss: 0.7954
# Epoch 374/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7635 - g_loss: 0.8026
# Epoch 375/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.7117 - g_loss: 0.8428
# Epoch 376/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6652 - g_loss: 0.8831
# Epoch 377/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6581 - g_loss: 0.8877
# Epoch 378/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6471 - g_loss: 0.8966
# Epoch 379/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6667 - g_loss: 0.8683
# Epoch 380/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6798 - g_loss: 0.8393
# Epoch 381/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6788 - g_loss: 0.8547
# Epoch 382/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6739 - g_loss: 0.8704
# Epoch 383/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6717 - g_loss: 0.8947
# Epoch 384/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6711 - g_loss: 0.9096
# Epoch 385/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6716 - g_loss: 0.9324
# Epoch 386/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6758 - g_loss: 0.9416
# Epoch 387/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6727 - g_loss: 0.9290
# Epoch 388/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6737 - g_loss: 0.9260
# Epoch 389/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6739 - g_loss: 0.9273
# Epoch 390/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6745 - g_loss: 0.9256
# Epoch 391/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6749 - g_loss: 0.9230
# Epoch 392/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6716 - g_loss: 0.9166
# Epoch 393/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6677 - g_loss: 0.9099
# Epoch 394/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6618 - g_loss: 0.9292
# Epoch 395/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6547 - g_loss: 0.9431
# Epoch 396/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6502 - g_loss: 0.9667
# Epoch 397/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6448 - g_loss: 0.9794
# Epoch 398/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6440 - g_loss: 1.0045
# Epoch 399/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6510 - g_loss: 1.0178
# Epoch 400/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6703 - g_loss: 0.9904
# Epoch 401/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6801 - g_loss: 0.9584
# Epoch 402/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6797 - g_loss: 0.9467
# Epoch 403/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6794 - g_loss: 0.9422
# Epoch 404/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6792 - g_loss: 0.9437
# Epoch 405/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6785 - g_loss: 0.9471
# Epoch 406/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6782 - g_loss: 0.9525
# Epoch 407/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6775 - g_loss: 0.9590
# Epoch 408/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6780 - g_loss: 0.9659
# Epoch 409/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6775 - g_loss: 0.9736
# Epoch 410/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6782 - g_loss: 0.9760
# Epoch 411/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6784 - g_loss: 0.9710
# Epoch 412/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6779 - g_loss: 0.9701
# Epoch 413/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6770 - g_loss: 0.9617
# Epoch 414/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6790 - g_loss: 0.9637
# Epoch 415/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6803 - g_loss: 0.9692
# Epoch 416/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6787 - g_loss: 0.9700
# Epoch 417/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6786 - g_loss: 0.9710
# Epoch 418/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6781 - g_loss: 0.9658
# Epoch 419/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6778 - g_loss: 0.9639
# Epoch 420/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6782 - g_loss: 0.9625
# Epoch 421/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6780 - g_loss: 0.9621
# Epoch 422/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6774 - g_loss: 0.9551
# Epoch 423/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6790 - g_loss: 0.9515
# Epoch 424/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 72ms/step - d_loss: 0.6793 - g_loss: 0.9515
# Epoch 425/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6768 - g_loss: 0.9466
# Epoch 426/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6754 - g_loss: 0.9393
# Epoch 427/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6781 - g_loss: 0.9374
# Epoch 428/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6775 - g_loss: 0.9354
# Epoch 429/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6779 - g_loss: 0.9374
# Epoch 430/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6779 - g_loss: 0.9361
# Epoch 431/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6780 - g_loss: 0.9377
# Epoch 432/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6786 - g_loss: 0.9475
# Epoch 433/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6785 - g_loss: 0.9510
# Epoch 434/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6710 - g_loss: 0.9408
# Epoch 435/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.3819 - g_loss: 1.9746
# Epoch 436/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.4858 - g_loss: 2.1459
# Epoch 437/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6181 - g_loss: 1.0823
# Epoch 438/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6040 - g_loss: 1.0275
# Epoch 439/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6303 - g_loss: 1.0300
# Epoch 440/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6598 - g_loss: 0.9923
# Epoch 441/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6696 - g_loss: 0.9662
# Epoch 442/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6667 - g_loss: 0.9735
# Epoch 443/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6699 - g_loss: 0.9864
# Epoch 444/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6716 - g_loss: 0.9892
# Epoch 445/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6726 - g_loss: 0.9976
# Epoch 446/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6736 - g_loss: 1.0018
# Epoch 447/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6751 - g_loss: 1.0083
# Epoch 448/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6746 - g_loss: 1.0121
# Epoch 449/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6740 - g_loss: 1.0165
# Epoch 450/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6740 - g_loss: 1.0181
# Epoch 451/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6546 - g_loss: 0.9894
# Epoch 452/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6535 - g_loss: 0.9813
# Epoch 453/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6502 - g_loss: 1.0229
# Epoch 454/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6496 - g_loss: 1.0470
# Epoch 455/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6506 - g_loss: 1.0732
# Epoch 456/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6531 - g_loss: 1.0982
# Epoch 457/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6611 - g_loss: 1.1120
# Epoch 458/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6625 - g_loss: 1.0997
# Epoch 459/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6784 - g_loss: 1.0685
# Epoch 460/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6809 - g_loss: 1.0368
# Epoch 461/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6804 - g_loss: 1.0311
# Epoch 462/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6790 - g_loss: 1.0282
# Epoch 463/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6778 - g_loss: 1.0392
# Epoch 464/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6838 - g_loss: 1.0698
# Epoch 465/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6791 - g_loss: 1.0575
# Epoch 466/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6793 - g_loss: 1.0594
# Epoch 467/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6789 - g_loss: 1.0540
# Epoch 468/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6776 - g_loss: 1.0531
# Epoch 469/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6781 - g_loss: 1.0553
# Epoch 470/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6788 - g_loss: 1.0501
# Epoch 471/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6826 - g_loss: 1.0503
# Epoch 472/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6800 - g_loss: 1.0326
# Epoch 473/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6789 - g_loss: 1.0338
# Epoch 474/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6790 - g_loss: 1.0334
# Epoch 475/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6789 - g_loss: 1.0259
# Epoch 476/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6789 - g_loss: 1.0248
# Epoch 477/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6786 - g_loss: 1.0277
# Epoch 478/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6781 - g_loss: 1.0276
# Epoch 479/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6773 - g_loss: 1.0173
# Epoch 480/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6774 - g_loss: 1.0186
# Epoch 481/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6744 - g_loss: 1.0020
# Epoch 482/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6789 - g_loss: 0.9970
# Epoch 483/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6787 - g_loss: 0.9923
# Epoch 484/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6806 - g_loss: 0.9966
# Epoch 485/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6771 - g_loss: 0.9778
# Epoch 486/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6781 - g_loss: 0.9917
# Epoch 487/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6767 - g_loss: 0.9917
# Epoch 488/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6788 - g_loss: 0.9938
# Epoch 489/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6773 - g_loss: 0.9916
# Epoch 490/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6775 - g_loss: 0.9925
# Epoch 491/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.4958 - g_loss: 1.4391
# Epoch 492/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.3624 - g_loss: 2.4666
# Epoch 493/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.3546 - g_loss: 2.5671
# Epoch 494/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.3483 - g_loss: 2.6241
# Epoch 495/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - d_loss: 0.6790 - g_loss: 1.2484
# Epoch 496/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6250 - g_loss: 1.0444
# Epoch 497/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.6203 - g_loss: 1.1708
# Epoch 498/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.5974 - g_loss: 1.2369
# Epoch 499/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.5645 - g_loss: 1.2678
# Epoch 500/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 34s 72ms/step - d_loss: 0.5589 - g_loss: 1.3275

# %%
plt.suptitle('Loss')
plt.plot(hist.history['d_loss'], label='d_loss')
plt.plot(hist.history['g_loss'], label='g_loss')
plt.legend()
plt.show()

# %%
generator.save('generator.h5')
discriminator.save('discriminator.h5')

# %%
#look at the final outputs
generator.load_weights(os.path.join('Results', 'generator.h5'))
imgs = generator.predict(tf.random.normal((6, 128, 1)))
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(5,5))
for r in range(2): 
    for c in range(3): 
        ax[r][c].imshow(imgs[(r+1)*(c+1)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step

# %% [markdown]
# From the output graph, we can see that the losses of the generator and discriminator have generally _settled to an equilibrium_ around each other, except for some sudden spikes. The data suggests that optimal results would have been obtained at around **the 350 epoch mark**. From the output above, we can see that the generator has become fairly proficient in generating the numbers **7** and **4**. If we look at the output images stored [here](Results/digits), we can see that it has also become very good at generating the number **2**. Due to the nature of the training of this GAN, we have no control over which output exactly it will generate. This can be done using a **conditional GAN**, which we have explored in the final project.
